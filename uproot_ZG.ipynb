# %% [markdown]
# ## 导入包

# %%
import uproot ## means uproot4
import matplotlib as mpl
import matplotlib.pyplot as plt
import mplhep as hep
import boost_histogram as bh
import numpy as np
import awkward as ak
from cycler import cycler
from math import log

# %%
import sys, os

# %% [markdown]
# ## 导入数据

# %% [markdown]
# # SM(LO)

# %% [markdown]
# ## SM1-3

# %%
use_helvet = False ## true: use helvetica for plots, make sure the system have the font installed
if use_helvet:
    CMShelvet = hep.style.CMS
    CMShelvet['font.sans-serif'] = ['Helvetica', 'Arial']
    plt.style.use(CMShelvet)
else:
    plt.style.use(hep.style.CMS)

filedict_sm13={
    'sm13': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_SM_LO/ZG_nTGC_NANOGEN_sm100to300.root'
}

events_sm13 = {key: {} for key in filedict_sm13}

for key in filedict_sm13:
    events_sm13[key] = uproot.lazy({filedict_sm13[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])

    
##录入pt
photon_pt_sm13 = events_sm13['sm13']['LHEPart_pt'][:,2:7][events_sm13['sm13']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==13]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-13]
print(photon_pt_sm13)
# Out:
# [[120], [204], [112], [107], [108], [125, ... [133], [109], [109], [101], [226]]

# %% [markdown]
# ## SM3-5

# %%
filedict_sm35={
    'sm35': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_SM_LO/ZG_nTGC_NANOGEN_sm300to500.root'
}

events_sm35 = {key: {} for key in filedict_sm35}

for key in filedict_sm35:
    events_sm35[key] = uproot.lazy({filedict_sm35[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])

    
##录入pt
photon_pt_sm35 = events_sm35['sm35']['LHEPart_pt'][:,2:7][events_sm35['sm35']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==13]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-13]
print(photon_pt_sm35)
# Out:
# [[357], [301], [450], [329], [307], [301, ... [330], [428], [352], [318], [495]]

# %% [markdown]
# ## SM5-6

# %%
filedict_sm56={
    'sm56': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_SM_LO/ZG_nTGC_NANOGEN_sm500to600.root'
}

events_sm56 = {key: {} for key in filedict_sm56}

for key in filedict_sm56:
    events_sm56[key] = uproot.lazy({filedict_sm56[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])
    
##录入pt
photon_pt_sm56 = events_sm56['sm56']['LHEPart_pt'][:,2:7][events_sm56['sm56']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==13]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-13]
print(photon_pt_sm56)
# Out:
# [[512], [577], [536], [512], [523], [523, ... [574], [584], [530], [517], [541]]

# %% [markdown]
# ## SM6-7

# %%
filedict_sm67={
    'sm67': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_SM_LO/ZG_nTGC_NANOGEN_sm600to700.root'
}

events_sm67 = {key: {} for key in filedict_sm67}

for key in filedict_sm67:
    events_sm67[key] = uproot.lazy({filedict_sm67[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])
    
##录入pt
photon_pt_sm67 = events_sm67['sm67']['LHEPart_pt'][:,2:7][events_sm67['sm67']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==13]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-13]
print(photon_pt_sm67)
# Out:
# [[659], [672], [605], [648], [649], [665, ... [642], [691], [625], [647], [626]]

# %% [markdown]
# ## SM7-1

# %%
filedict_sm78={
    'sm78': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_SM_LO/ZG_nTGC_NANOGEN_sm700to1000.root'
}

events_sm78 = {key: {} for key in filedict_sm78}

for key in filedict_sm78:
    events_sm78[key] = uproot.lazy({filedict_sm78[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])
    
    
##录入pt
photon_pt_sm78 = events_sm78['sm78']['LHEPart_pt'][:,2:7][events_sm78['sm78']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==13]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-13]
print(photon_pt_sm78)
# Out:
# [[836], [788], [954], [797], [771], [853, ... [704], [713], [812], [877], [809]]

# %% [markdown]
# ## SM1000-3000

# %%
filedict_sm1030={
    'sm1030': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_SM_LO/ZG_nTGC_NANOGEN_sm1000to3000.root'
}

events_sm1030 = {key: {} for key in filedict_sm1030}

for key in filedict_sm1030:
    events_sm1030[key] = uproot.lazy({filedict_sm1030[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])
    
    
##录入pt
photon_pt_sm1030 = events_sm1030['sm1030']['LHEPart_pt'][:,2:7][events_sm1030['sm1030']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==13]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-13]
print(photon_pt_sm1030)
# Out:
# [[1.03e+03], [1.88e+03], [1.03e+03], ... [1.44e+03], [1.37e+03], [1.03e+03]]

# %% [markdown]
# ## SM3-i

# %%
filedict_sm3i={
    'sm3i': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_SM_LO/ZG_nTGC_NANOGEN_sm3000toinfinite.root'
}

events_sm3i = {key: {} for key in filedict_sm3i}

for key in filedict_sm3i:
    events_sm3i[key] = uproot.lazy({filedict_sm3i[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])
    
    
##录入pt
photon_pt_sm3i = events_sm3i['sm3i']['LHEPart_pt'][:,2:7][events_sm3i['sm3i']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==13]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-13]
print(photon_pt_sm3i)
# Out:
# [[3.03e+03], [3.01e+03], [3.05e+03], ... [3.47e+03], [3.39e+03], [3.26e+03]]

# %% [markdown]
# ## 试错

# %%
filedict_smtest={
    'smtest': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_SM_LO/ZG_nTGC_NANOGEN_sm100to300.root'
}

events_smtest = {key: {} for key in filedict_smtest}

for key in filedict_smtest:
    events_smtest[key] = uproot.lazy({filedict_smtest[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])
    
    
##录入pt
photon_pt_smtest = events_smtest['smtest']['LHEPart_pt'][:,2:7][events_smtest['smtest']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==13]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-13]
print(photon_pt_smtest)
#print(np.array(values_smtest).shape)
# Out:
# [[120], [204], [112], [107], [108], [125, ... [133], [109], [109], [101], [226]]

# %%
xsec = sum(events_smtest['smtest']['LHEWeight_originalXWGTUP']*events_smtest['smtest']['LHEReweightingWeight'])/10000
print(xsec)
# Out:
# [2e-05, 0.002, 7.95e-08, 4.37e-07]

# %%
def plot(sample, variable, bins=20, x_min=0, x_max=6100, density=False, stack=False):
    ## canvas initializing
    colorlist=['red', 'blue', 'green', 'black', 'cyan', 'darkorange', 'darkviolet', 'SlateGray', 'HotPink', 'LightSkyBlue']
    mpl.rcParams['axes.prop_cycle'] = cycler(color=colorlist)
    #f, ax = plt.subplots()
    plt.figure(figsize=(9,9))
    ax=plt.gca()
    plt.grid()
    hep.cms.label(data=False, year=2022, ax=ax)
#    hep.cms.label(data=False, year=MC, ax=ax)
    
    values_sm35 = np.squeeze(photon_pt_sm35)
    values_sm56 = np.squeeze(photon_pt_sm56)
    values_sm3i = np.squeeze(photon_pt_sm3i)

    values_smp = np.vstack((values_sm35,values_sm56))
    print(values_smp)
    print(np.array(values_smp).shape) 
    values_smt =np.r_[values_sm35,values_sm56]
    print(values_smt)
    values_sm = np.squeeze(values_smp)
    print(values_sm)
    print(np.array(values_sm).shape) 
    ## plot
    hist_smtest = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
#    values = np.squeeze(sample[variable][sample['Particle.PID']==13])

    values_smtest = np.squeeze(photon_pt_smtest)

    hist_smtest.fill(values_smtest)
    

    h_smtest, err_smtest = hist_smtest.view().value*8.88*(10**(-5)), np.sqrt(hist_smtest.view().variance)*8.88*(10**(-5))
#        h_sm3i, err_sm3i = hist_sm3i.view().value*8.88*(10**(-5)), np.sqrt(hist_sm3i.view().variance)*8.88*(10**(-5))

    hep.histplot(h_smtest, bins=hist_smtest.axes[0].edges, yerr=err_smtest, label='sm_pt100to800', histtype='step', density=density, stack=stack)
    # or you can specify color='blue' in the above function to cover colorlist (you could comment out colorlist too) 


    ## axises
#    plt.xlim(x_min, x_max)
    plt.xlim(0, 6100)
#    plt.ylim(0, ax.get_ylim()[1]*1.1) 
    ax.ticklabel_format(useOffset=False, style='plain')
    plt.yscale('log') 
    
    if density==False:
        plt.ylabel('Events', fontsize=20, ha='right', y=1)
    elif density==True:    
        plt.ylabel('A.U.', fontsize=20, ha='right', y=1)
    plt.xlabel('photon_pt', fontsize=20, ha='right', x=1)

    plt.xticks(size=16)
    plt.yticks(size=16)

    ## title, text and legend
    #plt.title('ROC Curve of HWW4q vs. QCD', fontsize=24,color="black")
    plt.legend(loc="best", ncol=1, frameon=False, fontsize=20)
    #plt.text(0.96*ax.get_xlim()[1], ax.get_ylim()[1]*0.72,"At "+r"$\mathrm{m^{gen}_{H}=}$"+f"{Higgsmass} GeV", fontsize=24, color="black", ha='right')


    ## finalizing
    if density==True:   suffix='_AU'
    if stack==True:     suffix='_stack'
#    plt.savefig("plots/"+'M_mumu2'+suffix+".pdf", bbox_inches='tight')
    plt.savefig("plots/"+'test_photon_pt'+".pdf", bbox_inches='tight')
    plt.show()

# %%
#plot(sample=events['mc'], variable='Particle.PT')
plot(sample=events_smtest['smtest'],  variable='test_photon_pt')
#plot

# %%
events_sm3i['sm3i'].fields
# Out:
# ['run',
#  'luminosityBlock',
#  'event',
#  'HTXS_Higgs_pt',
#  'HTXS_Higgs_y',
#  'HTXS_stage1_1_cat_pTjet25GeV',
#  'HTXS_stage1_1_cat_pTjet30GeV',
#  'HTXS_stage1_1_fine_cat_pTjet25GeV',
#  'HTXS_stage1_1_fine_cat_pTjet30GeV',
#  'HTXS_stage1_2_cat_pTjet25GeV',
#  'HTXS_stage1_2_cat_pTjet30GeV',
#  'HTXS_stage1_2_fine_cat_pTjet25GeV',
#  'HTXS_stage1_2_fine_cat_pTjet30GeV',
#  'HTXS_stage_0',
#  'HTXS_stage_1_pTjet25',
#  'HTXS_stage_1_pTjet30',
#  'HTXS_njets25',
#  'HTXS_njets30',
#  'nGenJetAK8',
#  'GenJetAK8_eta',
#  'GenJetAK8_mass',
#  'GenJetAK8_phi',
#  'GenJetAK8_pt',
#  'nGenJet',
#  'GenJet_eta',
#  'GenJet_mass',
#  'GenJet_phi',
#  'GenJet_pt',
#  'nGenPart',
#  'GenPart_eta',
#  'GenPart_mass',
#  'GenPart_phi',
#  'GenPart_pt',
#  'GenPart_genPartIdxMother',
#  'GenPart_pdgId',
#  'GenPart_status',
#  'GenPart_statusFlags',
#  'Generator_binvar',
#  'Generator_scalePDF',
#  'Generator_weight',
#  'Generator_x1',
#  'Generator_x2',
#  'Generator_xpdf1',
# ...

# %%
print(events_sm1030['sm1030']['LHEWeight_originalXWGTUP'])
# Out:
# [1.01e-05, 1.01e-05, 1.01e-05, 1.01e-05, ... 1.07e-05, 1.07e-05, 1.07e-05, 1.07e-05]

# %%
for event_photon_truth in (np.abs(events['gen']['LHEPart_pdgId'][:,2:7])==13):
    print(event_photon_truth)
# Out:
# [False, False, False]
# [True, True, False]
# [True, True, False]
# [False, False, False]
# [True, True, False]
# [False, False, False]
# [False, False, False]
# [True, True, False]
# [True, True, False]
# [True, True, False]
# [False, False, False]
# [False, False, False]
# [False, False, False]
# [False, False, False]
# [False, False, False]
# [False, False, False]
# [True, True, False]
# [False, False, False]
# [True, True, False]
# [False, False, False]
# [False, False, False]
# [False, False, False]
# [True, True, False]
# [True, True, False]
# [True, True, False]
# [True, True, False]
# [True, True, False]
# [False, False, False]
# [True, True, False]
# [False, False, False]
# [True, True, False]
# [True, True, False]
# [False, False, False]
# [True, True, False]
# [True, True, False]
# [True, True, False]
# [False, False, False]
# [False, False, False]
# [False, False, False]
# [True, True, False]
# [True, True, False]
# [True, True, False]
# [False, False, False]
# ...

# %%
#events['gen']['LHEPart_pt']
#events['gen']['LHEPart_pt'][:,2:7]
events['gen']['LHEPart_pt'][:,2:7][events['gen']['LHEPart_pdgId'][:,2:7]==22]
# Out:
# <Array [[512], [577], ... [517], [541]] type='10000 * var * float32'>

# %%
photon_pt = events['gen']['LHEPart_pt'][:,2:7][events['gen']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==13]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-13]
print(photon_pt)
# Out:
# [[702], [709], [710], [739], [712], [747, ... [725], [763], [742], [702], [720]]

# %%
np.squeeze(photon_pt)
# Out:
# <Array [57.7, 21.2, 28.6, ... 16.8, 34.4, 24] type='1000 * float32'>

# %%
events['mc']['Particle.PT'][events['mc']['Particle.PID']==13]
# Out:
# <Array [[18.8], [27.3], ... [15.7], [12]] type='10000 * var * float64'>

# %%
values_sm35 = np.squeeze(photon_pt_sm35)
values_sm56 = np.squeeze(photon_pt_sm56)
values_sm3i = np.squeeze(photon_pt_sm3i)
print(values_sm3i)
print(np.array(values_sm3i).shape)
print(np.array(values_sm35).shape)

values_smp = np.vstack((values_sm35,values_sm56))
print(values_smp)
print(np.array(values_smp).shape) 
values_smt =np.r_[values_sm35,values_sm56]
print(values_smt)
values_sm = np.squeeze(values_smp)
print(values_sm)
print(np.array(values_sm).shape)
# Out:
# [735, 808, 705, 829, 711, 783, ... 3.22e+03, 3.21e+03, 3.85e+03, 3.04e+03, 3.32e+03]
# (10000,)
# (10000,)
# [[357, 301, 450, 329, 307, 301, 320, 311, ... 505, 512, 574, 584, 530, 517, 541]]
# (2, 10000)
# [357.39062 300.95312 450.09375 ... 529.71875 517.25    540.90625]
# [[357, 301, 450, 329, 307, 301, 320, 311, ... 505, 512, 574, 584, 530, 517, 541]]
# (2, 10000)

# %%
##weight
    weight_sm13 = 0.1679*(10**5)
    weight_sm35 = 0.003305*(10**5)
    weight_sm56 = 0.0002449*(10**5)
    weight_sm67 = 9.645
    weight_sm78 = 6.96
#    weight_sm1030 =
    weight_sm3i = 8.88*(10**(-5)

# %% [markdown]
# ## 画图

# %%
def plot(sample, variable, bins=20, x_min=0, x_max=6100, density=False, stack=False):
    ## canvas initializing
    colorlist=['red', 'blue', 'green', 'black', 'cyan', 'darkorange', 'darkviolet', 'SlateGray', 'HotPink', 'LightSkyBlue']
    mpl.rcParams['axes.prop_cycle'] = cycler(color=colorlist)
    #f, ax = plt.subplots()
    plt.figure(figsize=(9,9))
    ax=plt.gca()
    plt.grid()
    hep.cms.label(data=False, year=2022, ax=ax)
#    hep.cms.label(data=False, year=MC, ax=ax)

## plot
    hist_sm13 = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_sm35 = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_sm56 = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_sm67 = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_sm78 = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_sm1030 = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_sm3i = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())

#    hist_sm = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
#    values = np.squeeze(sample[variable][sample['Particle.PID']==13])

    values_sm13 = np.squeeze(photon_pt_sm13)
    values_sm35 = np.squeeze(photon_pt_sm35)
    values_sm56 = np.squeeze(photon_pt_sm56)
    values_sm67 = np.squeeze(photon_pt_sm67)
    values_sm78 = np.squeeze(photon_pt_sm78)
    values_sm1030 = np.squeeze(photon_pt_sm1030)
    values_sm3i = np.squeeze(photon_pt_sm3i)

#    values_smt =np.r_[values_sm13,values_sm35,values_sm56,values_sm67,values_sm78,values_sm3i]
#    print(values_smt)
#    values_sm = np.squeeze(values_smt)
#    print(values_sm)

    hist_sm13.fill(values_sm13)
    hist_sm35.fill(values_sm35)
    hist_sm56.fill(values_sm56)
    hist_sm67.fill(values_sm67)
    hist_sm78.fill(values_sm78)
    hist_sm1030.fill(values_sm1030)
    hist_sm3i.fill(values_sm3i)

    h_sm13, err_sm13 = hist_sm13.view().value*0.1679*(10**5), np.sqrt(hist_sm13.view().variance)*0.1679*(10**5)
    h_sm35, err_sm35 = hist_sm35.view().value*0.003305*(10**5), np.sqrt(hist_sm35.view().variance)*0.003305*(10**5)
    h_sm56, err_sm56 = hist_sm56.view().value*0.0002449*(10**5), np.sqrt(hist_sm56.view().variance)*0.0002449*(10**5)
    h_sm67, err_sm67 = hist_sm67.view().value*9.645, np.sqrt(hist_sm67.view().variance)*9.645
    h_sm78, err_sm78 = hist_sm78.view().value*6.96, np.sqrt(hist_sm78.view().variance)*6.96
    h_sm1030, err_sm1030 = hist_sm1030.view().value*1.01, np.sqrt(hist_sm1030.view().variance)*1.01
    h_sm3i, err_sm3i = hist_sm3i.view().value*8.88*(10**(-5)), np.sqrt(hist_sm3i.view().variance)*8.88*(10**(-5))

#    h_sm, err_sm = hist_sm.view().value, np.sqrt(hist_sm.view().variance)
#    print(hist_sm.view())
 #   print(np.array(hist_sm.view()).shape)
 #   print(hist_sm13.view())
 #   print(np.array(hist_sm13.view()).shape)
#    h_sm = np.r_[h_sm13,h_sm35,h_sm56,h_sm67,h_sm78,h_sm3i]
#    print(np.array(h_sm).shape)
#    err_sm = np.r_[err_sm13,err_sm35,err_sm56,err_sm67,err_sm78,err_sm3i]

    hep.histplot(h_sm13, bins=hist_sm13.axes[0].edges, yerr=err_sm13, label='sm_pt100to300', histtype='step', density=density, stack=stack)
    hep.histplot(h_sm35, bins=hist_sm35.axes[0].edges, yerr=err_sm35, label='sm_pt300to500', histtype='step', density=density, stack=stack)
    hep.histplot(h_sm56, bins=hist_sm56.axes[0].edges, yerr=err_sm56, label='sm_pt500to600', histtype='step', density=density, stack=stack)
    hep.histplot(h_sm67, bins=hist_sm67.axes[0].edges, yerr=err_sm67, label='sm_pt600to700', histtype='step', density=density, stack=stack)
    hep.histplot(h_sm78, bins=hist_sm78.axes[0].edges, yerr=err_sm78, label='sm_pt700to1000', histtype='step', density=density, stack=stack)
    hep.histplot(h_sm1030, bins=hist_sm1030.axes[0].edges, yerr=err_sm1030, label='sm_pt1000to3000', histtype='step', density=density, stack=stack)
    hep.histplot(h_sm3i, bins=hist_sm3i.axes[0].edges, yerr=err_sm3i, label='sm_pt3000toinfinite', histtype='step', density=density, stack=stack)
#    hep.histplot(h_sm, bins=hist_sm.axes[0].edges, yerr=err_sm, label='sm_pt100to800', histtype='step', density=density, stack=stack)
    # or you can specify color='blue' in the above function to cover colorlist (you could comment out colorlist too) 


## axises
#    plt.xlim(x_min, x_max)
    plt.xlim(0, 6100)
#    plt.ylim(0, ax.get_ylim()[1]*1.1) 
    ax.ticklabel_format(useOffset=False, style='plain')
    plt.yscale('log') 

    if density==False:
        plt.ylabel('Events', fontsize=20, ha='right', y=1)
    elif density==True:    
        plt.ylabel('A.U.', fontsize=20, ha='right', y=1)
    plt.xlabel('photon_pt', fontsize=20, ha='right', x=1)

    plt.xticks(size=16)
    plt.yticks(size=16)

    ## title, text and legend
    #plt.title('ROC Curve of HWW4q vs. QCD', fontsize=24,color="black")
    plt.legend(loc="best", ncol=1, frameon=False, fontsize=20)
    #plt.text(0.96*ax.get_xlim()[1], ax.get_ylim()[1]*0.72,"At "+r"$\mathrm{m^{gen}_{H}=}$"+f"{Higgsmass} GeV", fontsize=24, color="black", ha='right')


    ## finalizing
    if density==True:   suffix='_AU'
    if stack==True:     suffix='_stack'
#    plt.savefig("plots/"+'M_mumu2'+suffix+".pdf", bbox_inches='tight')
    plt.savefig("plots/"+'test_photon_pt'+".pdf", bbox_inches='tight')
    plt.show()

# %%
#plot(sample=events['mc'], variable='Particle.PT')
plot(sample=events_sm13['sm13'],  variable='test_photon_pt')
#plot

# %% [markdown]
# # operator

# %% [markdown]
# ## opera1-3

# %%
use_helvet = False ## true: use helvetica for plots, make sure the system have the font installed
if use_helvet:
    CMShelvet = hep.style.CMS
    CMShelvet['font.sans-serif'] = ['Helvetica', 'Arial']
    plt.style.use(CMShelvet)
else:
    plt.style.use(hep.style.CMS)

filedict_opera13={
    'opera13': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_Opera/ZG_nTGC_NANOGEN_opera100to300.root'
}

events_opera13 = {key: {} for key in filedict_opera13}

for key in filedict_opera13:
    events_opera13[key] = uproot.lazy({filedict_opera13[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])

    
##录入pt
photon_pt_opera13 = events_opera13['opera13']['LHEPart_pt'][:,2:7][events_opera13['opera13']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==13]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-13]
print(photon_pt_opera13)
#print(events_opera13['opera13']['LHEReweightingWeight'])
#print(events_opera13['opera13']['LHEReweightingWeight'][:,2])
#photon_pt_opera13_h4z = photon_pt_opera13 * events_opera13['opera13']['LHEReweightingWeight'][:,0]
#print(photon_pt_opera13_h4z)
#photon_pt_opera13_h3a = photon_pt_opera13 * events_opera13['opera13']['LHEReweightingWeight'][:,2]
#print(photon_pt_opera13_h3a)
#photon_pt_opera13_h3z = photon_pt_opera13 * events_opera13['opera13']['LHEReweightingWeight'][:,3]
#print(photon_pt_opera13_h3z)
xsec_opera13 = sum(events_opera13['opera13']['LHEWeight_originalXWGTUP']*events_opera13['opera13']['LHEReweightingWeight'])/10000
print(xsec_opera13)
xsec_opera13_h4z = xsec_opera13[0]
#print(xsec_opera13_h4z)
xsec_opera13_h3a = xsec_opera13[2]
xsec_opera13_h3z = xsec_opera13[3]
print(events_opera13['opera13']['LHEReweightingWeight'])
# Out:
# [[156], [102], [147], [163], [140], [143, ... [117], [113], [126], [100], [109]]
# [0.147, 0.147, 0.147, 0.147]
# [[1, 1, 1, 1], [1, 1, 0.997, 0.994], [1, 1, ... 1.01], [1, 1, 1, 1], [1, 1, 1, 1]]

# %% [markdown]
# ## opera3-5

# %%
filedict_opera35={
    'opera35': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_Opera/ZG_nTGC_NANOGEN_opera300to500.root'
}

events_opera35 = {key: {} for key in filedict_opera35}

for key in filedict_opera35:
    events_opera35[key] = uproot.lazy({filedict_opera35[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])

    
##录入pt
photon_pt_opera35 = events_opera35['opera35']['LHEPart_pt'][:,2:7][events_opera35['opera35']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==35]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-35]
print(photon_pt_opera35) 
xsec_opera35 = sum(events_opera35['opera35']['LHEWeight_originalXWGTUP']*events_opera35['opera35']['LHEReweightingWeight'])/10000
print(xsec_opera35)
xsec_opera35_h4z = xsec_opera35[0]
print(xsec_opera35_h4z)
xsec_opera35_h3a = xsec_opera35[2]
xsec_opera35_h3z = xsec_opera35[3]
# Out:
# [[499], [349], [311], [421], [364], [342, ... [303], [397], [451], [399], [304]]
# [0.00293, 0.00424, 0.00291, 0.00298]
# 0.002930288901552558

# %% [markdown]
# ## opera5-6

# %%
filedict_opera56={
    'opera56': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_Opera/ZG_nTGC_NANOGEN_opera500to600.root'
}

events_opera56 = {key: {} for key in filedict_opera56}

for key in filedict_opera56:
    events_opera56[key] = uproot.lazy({filedict_opera56[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])
    
##录入pt
photon_pt_opera56 = events_opera56['opera56']['LHEPart_pt'][:,2:7][events_opera56['opera56']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==56]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-56]
print(photon_pt_opera56) 
xsec_opera56 = sum(events_opera56['opera56']['LHEWeight_originalXWGTUP']*events_opera56['opera56']['LHEReweightingWeight'])/10000
print(xsec_opera56)
xsec_opera56_h4z = xsec_opera56[0]
print(xsec_opera56_h4z)
xsec_opera56_h3a = xsec_opera56[2]
xsec_opera56_h3z = xsec_opera56[3]
print(events_opera56['opera56']['LHEReweightingWeight'])
# Out:
# [[538], [595], [512], [537], [528], [514, ... [576], [505], [531], [512], [544]]
# [0.000229, 0.00112, 0.000223, 0.00025]
# 0.0002293117286171764
# [[1.01, 1.05, 0.987, 0.971], [1, 1, 1, ... 1, 0.999, 0.998], [1, 1.01, 0.998, 0.995]]

# %% [markdown]
# ## opera6-7

# %%
filedict_opera67={
    'opera67': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_Opera/ZG_nTGC_NANOGEN_opera600to700.root'
}

events_opera67 = {key: {} for key in filedict_opera67}

for key in filedict_opera67:
    events_opera67[key] = uproot.lazy({filedict_opera67[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])
    
##录入pt
photon_pt_opera67 = events_opera67['opera67']['LHEPart_pt'][:,2:7][events_opera67['opera67']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==67]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-67]
print(photon_pt_opera67)
xsec_opera67 = sum(events_opera67['opera67']['LHEWeight_originalXWGTUP']*events_opera67['opera67']['LHEReweightingWeight'])/10000
print(xsec_opera67)
xsec_opera67_h4z = xsec_opera67[0]
print(xsec_opera67_h4z)
xsec_opera67_h3a = xsec_opera67[2]
xsec_opera67_h3z = xsec_opera67[3]
# Out:
# [[644], [600], [641], [657], [607], [637, ... [639], [626], [658], [662], [655]]
# [0.000103, 0.00181, 9.12e-05, 0.000117]
# 0.0001029268023557961

# %% [markdown]
# ## opera7-1

# %%
filedict_opera71={
    'opera71': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_Opera/ZG_nTGC_NANOGEN_opera700to1000.root'
}

events_opera71 = {key: {} for key in filedict_opera71}

for key in filedict_opera71:
    events_opera71[key] = uproot.lazy({filedict_opera71[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])
    
    
##录入pt
photon_pt_opera71 = events_opera71['opera71']['LHEPart_pt'][:,2:7][events_opera71['opera71']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==71]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-71]
print(photon_pt_opera71) 
xsec_opera71 = sum(events_opera71['opera71']['LHEWeight_originalXWGTUP']*events_opera71['opera71']['LHEReweightingWeight'])/10000
print(xsec_opera71)
xsec_opera71_h4z = xsec_opera71[0]
print(xsec_opera71_h4z)
xsec_opera71_h3a = xsec_opera71[2]
xsec_opera71_h3z = xsec_opera71[3]
# Out:
# [[724], [843], [744], [807], [960], [919, ... [877], [919], [744], [752], [739]]
# [0.000104, 0.00414, 8.25e-05, 0.000149]
# 0.00010372610267950222

# %% [markdown]
# ## opera1000-3000

# %%
filedict_opera1030={
    'opera1030': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_Opera/ZG_nTGC_NANOGEN_opera1000to3000.root'
}

events_opera1030 = {key: {} for key in filedict_opera1030}

for key in filedict_opera1030:
    events_opera1030[key] = uproot.lazy({filedict_opera1030[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])
    
    
##录入pt
photon_pt_opera1030 = events_opera1030['opera1030']['LHEPart_pt'][:,2:7][events_opera1030['opera1030']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==1030]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-1030]
print(photon_pt_opera1030)
xsec_opera1030 = sum(events_opera1030['opera1030']['LHEWeight_originalXWGTUP']*events_opera1030['opera1030']['LHEReweightingWeight'])/10000
print(xsec_opera1030)
xsec_opera1030_h4z = xsec_opera1030[0]
print(xsec_opera1030_h4z)
xsec_opera1030_h3a = xsec_opera1030[2]
xsec_opera1030_h3z = xsec_opera1030[3]
# Out:
# [[1.04e+03], [1.18e+03], [1.02e+03], ... [1.1e+03], [1.16e+03], [1.07e+03]]
# [0.000416, 0.0406, 4.01e-05, 0.000148]
# 0.0004162758414167911

# %% [markdown]
# ## opera3-i

# %%
filedict_opera3i={
    'opera3i': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_Opera/ZG_nTGC_NANOGEN_opera3000toinfinite.root'
}

events_opera3i = {key: {} for key in filedict_opera3i}

for key in filedict_opera3i:
    events_opera3i[key] = uproot.lazy({filedict_opera3i[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])
    
    
##录入pt
photon_pt_opera3i = events_opera3i['opera3i']['LHEPart_pt'][:,2:7][events_opera3i['opera3i']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==3i]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-3i]
print(photon_pt_opera3i) 
xsec_opera3i = sum(events_opera3i['opera3i']['LHEWeight_originalXWGTUP']*events_opera3i['opera3i']['LHEReweightingWeight'])/10000
print(xsec_opera3i)
xsec_opera3i_h4z = xsec_opera3i[0]
print(xsec_opera3i_h4z)
xsec_opera3i_h3a = xsec_opera3i[2]
xsec_opera3i_h3z = xsec_opera3i[3]
# Out:
# [[3.26e+03], [3.54e+03], [3.05e+03], ... [3.08e+03], [3.98e+03], [3.02e+03]]
# [0.000204, 0.0204, 7.97e-07, 4.33e-06]
# 0.000203742238227278

# %% [markdown]
# ## 画图

# %%
def plot(sample, variable, bins=20, x_min=0, x_max=6100, density=False, stack=False):
    ## canvas initializing
    colorlist=['red', 'blue', 'green', 'black', 'cyan', 'darkorange', 'darkviolet', 'SlateGray', 'HotPink', 'LightSkyBlue']
    mpl.rcParams['axes.prop_cycle'] = cycler(color=colorlist)
    #f, ax = plt.subplots()
    plt.figure(figsize=(9,9))
    ax=plt.gca()
    plt.grid()
    hep.cms.label(data=False, year=2022, ax=ax)
#    hep.cms.label(data=False, year=MC, ax=ax)
    
    
    ## plot
    hist_opera13_h4z = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_opera35_h4z = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_opera56_h4z = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_opera67_h4z = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_opera71_h4z = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_opera1030_h4z = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_opera3i_h4z = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
#    hist_opera = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
#    values = np.squeeze(sample[variable][sample['Particle.PID']==13])

    values_opera13_h4z = np.squeeze(photon_pt_opera13)
    values_opera35_h4z = np.squeeze(photon_pt_opera35)
    values_opera56_h4z = np.squeeze(photon_pt_opera56)
    values_opera67_h4z = np.squeeze(photon_pt_opera67)
    values_opera71_h4z = np.squeeze(photon_pt_opera71)
    values_opera1030_h4z = np.squeeze(photon_pt_opera1030)
    values_opera3i_h4z = np.squeeze(photon_pt_opera3i)
#    values_opera = np.squeeze(photon_pt_opera13 + photon_pt_opera35)
    
    hist_opera13_h4z.fill(values_opera13_h4z)
    hist_opera35_h4z.fill(values_opera35_h4z)
    hist_opera56_h4z.fill(values_opera56_h4z)
    hist_opera67_h4z.fill(values_opera67_h4z)
    hist_opera71_h4z.fill(values_opera71_h4z)
    hist_opera1030_h4z.fill(values_opera1030_h4z)
    hist_opera3i_h4z.fill(values_opera3i_h4z)
#    hist_opera.fill(values_opera)
    
    h_opera13_h4z, err_opera13_h4z = hist_opera13_h4z.view().value*xsec_opera13_h4z, np.sqrt(hist_opera13_h4z.view().variance)*xsec_opera13_h4z
    h_opera35_h4z, err_opera35_h4z = hist_opera35_h4z.view().value*xsec_opera35_h4z, np.sqrt(hist_opera35_h4z.view().variance)*xsec_opera35_h4z
    h_opera56_h4z, err_opera56_h4z = hist_opera56_h4z.view().value*xsec_opera56_h4z, np.sqrt(hist_opera56_h4z.view().variance)*xsec_opera56_h4z
    h_opera67_h4z, err_opera67_h4z = hist_opera67_h4z.view().value*xsec_opera67_h4z, np.sqrt(hist_opera67_h4z.view().variance)*xsec_opera67_h4z
    h_opera71_h4z, err_opera71_h4z = hist_opera71_h4z.view().value*xsec_opera71_h4z, np.sqrt(hist_opera71_h4z.view().variance)*xsec_opera71_h4z
    h_opera1030_h4z, err_opera1030_h4z = hist_opera1030_h4z.view().value*xsec_opera1030_h4z, np.sqrt(hist_opera1030_h4z.view().variance)*xsec_opera1030_h4z
    h_opera3i_h4z, err_opera3i_h4z = hist_opera3i_h4z.view().value*xsec_opera3i_h4z, np.sqrt(hist_opera3i_h4z.view().variance)*xsec_opera3i_h4z
    
#    h_opera, err_opera = hist_opera.view().value, np.sqrt(hist_opera.view().variance)
    
    
    hep.histplot(h_opera13_h4z, bins=hist_opera13_h4z.axes[0].edges, yerr=err_opera13_h4z, label='opera_pt100to300_h4z', histtype='step', density=density, stack=stack)
    hep.histplot(h_opera35_h4z, bins=hist_opera35_h4z.axes[0].edges, yerr=err_opera35_h4z, label='opera_pt300to500_h4z', histtype='step', density=density, stack=stack)
    hep.histplot(h_opera56_h4z, bins=hist_opera56_h4z.axes[0].edges, yerr=err_opera56_h4z, label='opera_pt500to600_h4z', histtype='step', density=density, stack=stack)
    hep.histplot(h_opera67_h4z, bins=hist_opera67_h4z.axes[0].edges, yerr=err_opera67_h4z, label='opera_pt600to700_h4z', histtype='step', density=density, stack=stack)
    hep.histplot(h_opera71_h4z, bins=hist_opera71_h4z.axes[0].edges, yerr=err_opera71_h4z, label='opera_pt700to1000_h4z', histtype='step', density=density, stack=stack)
    hep.histplot(h_opera1030_h4z, bins=hist_opera1030_h4z.axes[0].edges, yerr=err_opera1030_h4z, label='opera_pt1000to3000_h4z', histtype='step', density=density, stack=stack)
    hep.histplot(h_opera3i_h4z, bins=hist_opera3i_h4z.axes[0].edges, yerr=err_opera3i_h4z, label='opera_pt3000toinfinite_h4z', histtype='step', density=density, stack=stack)
    #    hep.histplot(h_opera, bins=hist_opera.axes[0].edges, yerr=err_opera, label='opera_pt100to800', histtype='step', density=density, stack=stack)
    # or you can specify color='blue' in the above function to cover colorlist (you could comment out colorlist too) 


    ## axises
#    plt.xlim(x_min, x_max)
    plt.xlim(0, 6100)
#    plt.ylim(0, ax.get_ylim()[1]*1.1) 
    ax.ticklabel_format(useOffset=False, style='plain')
    plt.yscale('log') 
    
    if density==False:
        plt.ylabel('Events', fontsize=20, ha='right', y=1)
    elif density==True:    
        plt.ylabel('A.U.', fontsize=20, ha='right', y=1)
    plt.xlabel('photon_pt', fontsize=20, ha='right', x=1)

    plt.xticks(size=16)
    plt.yticks(size=16)

    ## title, text and legend
    #plt.title('ROC Curve of HWW4q vs. QCD', fontsize=24,color="black")
    plt.legend(loc="best", ncol=1, frameon=False, fontsize=20)
    #plt.text(0.96*ax.get_xlim()[1], ax.get_ylim()[1]*0.72,"At "+r"$\mathrm{m^{gen}_{H}=}$"+f"{Higgoperaass} GeV", fontsize=24, color="black", ha='right')


    ## finalizing
    if density==True:   suffix='_AU'
    if stack==True:     suffix='_stack'
#    plt.savefig("plots/"+'M_mumu2'+suffix+".pdf", bbox_inches='tight')
    plt.savefig("plots/"+'test_photon_pt'+".pdf", bbox_inches='tight')
    plt.show()

# %%
#plot(sample=events['mc'], variable='Particle.PT')
plot(sample=events_opera35['opera35'],  variable='test_photon_pt')

# %%
def plot(sample, variable, bins=20, x_min=0, x_max=6100, density=False, stack=False):
    ## canvas initializing
    colorlist=['red', 'blue', 'green', 'black', 'cyan', 'darkorange', 'darkviolet', 'SlateGray', 'HotPink', 'LightSkyBlue']
    mpl.rcParams['axes.prop_cycle'] = cycler(color=colorlist)
    #f, ax = plt.subplots()
    plt.figure(figsize=(9,9))
    ax=plt.gca()
    plt.grid()
    hep.cms.label(data=False, year=2022, ax=ax)
#    hep.cms.label(data=False, year=MC, ax=ax)
    
    
    ## plot
    hist_opera13_h3a = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_opera35_h3a = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_opera56_h3a = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_opera67_h3a = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_opera71_h3a = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_opera1030_h3a = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_opera3i_h3a = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
#    hist_opera = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
#    values = np.squeeze(sample[variable][sample['Particle.PID']==13])

    values_opera13_h3a = np.squeeze(photon_pt_opera13)
    values_opera35_h3a = np.squeeze(photon_pt_opera35)
    values_opera56_h3a = np.squeeze(photon_pt_opera56)
    values_opera67_h3a = np.squeeze(photon_pt_opera67)
    values_opera71_h3a = np.squeeze(photon_pt_opera71)
    values_opera1030_h3a = np.squeeze(photon_pt_opera1030)
    values_opera3i_h3a = np.squeeze(photon_pt_opera3i)
#    values_opera = np.squeeze(photon_pt_opera13 + photon_pt_opera35)
    
    hist_opera13_h3a.fill(values_opera13_h3a)
    hist_opera35_h3a.fill(values_opera35_h3a)
    hist_opera56_h3a.fill(values_opera56_h3a)
    hist_opera67_h3a.fill(values_opera67_h3a)
    hist_opera71_h3a.fill(values_opera71_h3a)
    hist_opera1030_h3a.fill(values_opera1030_h3a)
    hist_opera3i_h3a.fill(values_opera3i_h3a)
#    hist_opera.fill(values_opera)
    
    h_opera13_h3a, err_opera13_h3a = hist_opera13_h3a.view().value*xsec_opera13_h3a, np.sqrt(hist_opera13_h3a.view().variance)*xsec_opera13_h3a
    h_opera35_h3a, err_opera35_h3a = hist_opera35_h3a.view().value*xsec_opera35_h3a, np.sqrt(hist_opera35_h3a.view().variance)*xsec_opera35_h3a
    h_opera56_h3a, err_opera56_h3a = hist_opera56_h3a.view().value*xsec_opera56_h3a, np.sqrt(hist_opera56_h3a.view().variance)*xsec_opera56_h3a
    h_opera67_h3a, err_opera67_h3a = hist_opera67_h3a.view().value*xsec_opera67_h3a, np.sqrt(hist_opera67_h3a.view().variance)*xsec_opera67_h3a
    h_opera71_h3a, err_opera71_h3a = hist_opera71_h3a.view().value*xsec_opera71_h3a, np.sqrt(hist_opera71_h3a.view().variance)*xsec_opera71_h3a
    h_opera1030_h3a, err_opera1030_h3a = hist_opera1030_h3a.view().value*xsec_opera1030_h3a, np.sqrt(hist_opera1030_h3a.view().variance)*xsec_opera1030_h3a
    h_opera3i_h3a, err_opera3i_h3a = hist_opera3i_h3a.view().value*xsec_opera3i_h3a, np.sqrt(hist_opera3i_h3a.view().variance)*xsec_opera3i_h3a
    
#    h_opera, err_opera = hist_opera.view().value, np.sqrt(hist_opera.view().variance)
    
    
    hep.histplot(h_opera13_h3a, bins=hist_opera13_h3a.axes[0].edges, yerr=err_opera13_h3a, label='opera_pt100to300_h3a', histtype='step', density=density, stack=stack)
    hep.histplot(h_opera35_h3a, bins=hist_opera35_h3a.axes[0].edges, yerr=err_opera35_h3a, label='opera_pt300to500_h3a', histtype='step', density=density, stack=stack)
    hep.histplot(h_opera56_h3a, bins=hist_opera56_h3a.axes[0].edges, yerr=err_opera56_h3a, label='opera_pt500to600_h3a', histtype='step', density=density, stack=stack)
    hep.histplot(h_opera67_h3a, bins=hist_opera67_h3a.axes[0].edges, yerr=err_opera67_h3a, label='opera_pt600to700_h3a', histtype='step', density=density, stack=stack)
    hep.histplot(h_opera71_h3a, bins=hist_opera71_h3a.axes[0].edges, yerr=err_opera71_h3a, label='opera_pt700to1000_h3a', histtype='step', density=density, stack=stack)
    hep.histplot(h_opera1030_h3a, bins=hist_opera1030_h3a.axes[0].edges, yerr=err_opera1030_h3a, label='opera_pt1000to3000_h3a', histtype='step', density=density, stack=stack)
    hep.histplot(h_opera3i_h3a, bins=hist_opera3i_h3a.axes[0].edges, yerr=err_opera3i_h3a, label='opera_pt3000toinfinite_h3a', histtype='step', density=density, stack=stack)
    #    hep.histplot(h_opera, bins=hist_opera.axes[0].edges, yerr=err_opera, label='opera_pt100to800', histtype='step', density=density, stack=stack)
    # or you can specify color='blue' in the above function to cover colorlist (you could comment out colorlist too) 


    ## axises
#    plt.xlim(x_min, x_max)
    plt.xlim(0, 6100)
#    plt.ylim(0, ax.get_ylim()[1]*1.1) 
    ax.ticklabel_format(useOffset=False, style='plain')
    plt.yscale('log') 
    
    if density==False:
        plt.ylabel('Events', fontsize=20, ha='right', y=1)
    elif density==True:    
        plt.ylabel('A.U.', fontsize=20, ha='right', y=1)
    plt.xlabel('photon_pt', fontsize=20, ha='right', x=1)

    plt.xticks(size=16)
    plt.yticks(size=16)

    ## title, text and legend
    #plt.title('ROC Curve of HWW4q vs. QCD', fontsize=24,color="black")
    plt.legend(loc="best", ncol=1, frameon=False, fontsize=20)
    #plt.text(0.96*ax.get_xlim()[1], ax.get_ylim()[1]*0.72,"At "+r"$\mathrm{m^{gen}_{H}=}$"+f"{Higgoperaass} GeV", fontsize=24, color="black", ha='right')


    ## finalizing
    if density==True:   suffix='_AU'
    if stack==True:     suffix='_stack'
#    plt.savefig("plots/"+'M_mumu2'+suffix+".pdf", bbox_inches='tight')
    plt.savefig("plots/"+'test_photon_pt'+".pdf", bbox_inches='tight')
    plt.show()

# %%
#plot(sample=events['mc'], variable='Particle.PT')
plot(sample=events_opera35['opera35'],  variable='test_photon_pt')

# %%
def plot(sample, variable, bins=20, x_min=0, x_max=6100, density=False, stack=False):
    ## canvas initializing
    colorlist=['red', 'blue', 'green', 'black', 'cyan', 'darkorange', 'darkviolet', 'SlateGray', 'HotPink', 'LightSkyBlue']
    mpl.rcParams['axes.prop_cycle'] = cycler(color=colorlist)
    #f, ax = plt.subplots()
    plt.figure(figsize=(9,9))
    ax=plt.gca()
    plt.grid()
    hep.cms.label(data=False, year=2022, ax=ax)
#    hep.cms.label(data=False, year=MC, ax=ax)
    
    
    ## plot
    hist_opera13_h3z = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_opera35_h3z = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_opera56_h3z = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_opera67_h3z = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_opera71_h3z = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_opera1030_h3z = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_opera3i_h3z = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
#    hist_opera = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
#    values = np.squeeze(sample[variable][sample['Particle.PID']==13])

    values_opera13_h3z = np.squeeze(photon_pt_opera13)
    values_opera35_h3z = np.squeeze(photon_pt_opera35)
    values_opera56_h3z = np.squeeze(photon_pt_opera56)
    values_opera67_h3z = np.squeeze(photon_pt_opera67)
    values_opera71_h3z = np.squeeze(photon_pt_opera71)
    values_opera1030_h3z = np.squeeze(photon_pt_opera1030)
    values_opera3i_h3z = np.squeeze(photon_pt_opera3i)
#    values_opera = np.squeeze(photon_pt_opera13 + photon_pt_opera35)
    
    hist_opera13_h3z.fill(values_opera13_h3z)
    hist_opera35_h3z.fill(values_opera35_h3z)
    hist_opera56_h3z.fill(values_opera56_h3z)
    hist_opera67_h3z.fill(values_opera67_h3z)
    hist_opera71_h3z.fill(values_opera71_h3z)
    hist_opera1030_h3z.fill(values_opera1030_h3z)
    hist_opera3i_h3z.fill(values_opera3i_h3z)
#    hist_opera.fill(values_opera)
    
    h_opera13_h3z, err_opera13_h3z = hist_opera13_h3z.view().value*xsec_opera13_h3z, np.sqrt(hist_opera13_h3z.view().variance)*xsec_opera13_h3z
    h_opera35_h3z, err_opera35_h3z = hist_opera35_h3z.view().value*xsec_opera35_h3z, np.sqrt(hist_opera35_h3z.view().variance)*xsec_opera35_h3z
    h_opera56_h3z, err_opera56_h3z = hist_opera56_h3z.view().value*xsec_opera56_h3z, np.sqrt(hist_opera56_h3z.view().variance)*xsec_opera56_h3z
    h_opera67_h3z, err_opera67_h3z = hist_opera67_h3z.view().value*xsec_opera67_h3z, np.sqrt(hist_opera67_h3z.view().variance)*xsec_opera67_h3z
    h_opera71_h3z, err_opera71_h3z = hist_opera71_h3z.view().value*xsec_opera71_h3z, np.sqrt(hist_opera71_h3z.view().variance)*xsec_opera71_h3z
    h_opera1030_h3z, err_opera1030_h3z = hist_opera1030_h3z.view().value*xsec_opera1030_h3z, np.sqrt(hist_opera1030_h3z.view().variance)*xsec_opera1030_h3z
    h_opera3i_h3z, err_opera3i_h3z = hist_opera3i_h3z.view().value*xsec_opera3i_h3z, np.sqrt(hist_opera3i_h3z.view().variance)*xsec_opera3i_h3z
    
#    h_opera, err_opera = hist_opera.view().value, np.sqrt(hist_opera.view().variance)
    
    
    hep.histplot(h_opera13_h3z, bins=hist_opera13_h3z.axes[0].edges, yerr=err_opera13_h3z, label='opera_pt100to300_h3z', histtype='step', density=density, stack=stack)
    hep.histplot(h_opera35_h3z, bins=hist_opera35_h3z.axes[0].edges, yerr=err_opera35_h3z, label='opera_pt300to500_h3z', histtype='step', density=density, stack=stack)
    hep.histplot(h_opera56_h3z, bins=hist_opera56_h3z.axes[0].edges, yerr=err_opera56_h3z, label='opera_pt500to600_h3z', histtype='step', density=density, stack=stack)
    hep.histplot(h_opera67_h3z, bins=hist_opera67_h3z.axes[0].edges, yerr=err_opera67_h3z, label='opera_pt600to700_h3z', histtype='step', density=density, stack=stack)
    hep.histplot(h_opera71_h3z, bins=hist_opera71_h3z.axes[0].edges, yerr=err_opera71_h3z, label='opera_pt700to1000_h3z', histtype='step', density=density, stack=stack)
    hep.histplot(h_opera1030_h3z, bins=hist_opera1030_h3z.axes[0].edges, yerr=err_opera1030_h3z, label='opera_pt1000to3000_h3z', histtype='step', density=density, stack=stack)
    hep.histplot(h_opera3i_h3z, bins=hist_opera3i_h3z.axes[0].edges, yerr=err_opera3i_h3z, label='opera_pt3000toinfinite_h3z', histtype='step', density=density, stack=stack)
    #    hep.histplot(h_opera, bins=hist_opera.axes[0].edges, yerr=err_opera, label='opera_pt100to800', histtype='step', density=density, stack=stack)
    # or you can specify color='blue' in the above function to cover colorlist (you could comment out colorlist too) 


    ## axises
#    plt.xlim(x_min, x_max)
    plt.xlim(0, 6100)
#    plt.ylim(0, ax.get_ylim()[1]*1.1) 
    ax.ticklabel_format(useOffset=False, style='plain')
    plt.yscale('log') 
    
    if density==False:
        plt.ylabel('Events', fontsize=20, ha='right', y=1)
    elif density==True:    
        plt.ylabel('A.U.', fontsize=20, ha='right', y=1)
    plt.xlabel('photon_pt', fontsize=20, ha='right', x=1)

    plt.xticks(size=16)
    plt.yticks(size=16)

    ## title, text and legend
    #plt.title('ROC Curve of HWW4q vs. QCD', fontsize=24,color="black")
    plt.legend(loc="best", ncol=1, frameon=False, fontsize=20)
    #plt.text(0.96*ax.get_xlim()[1], ax.get_ylim()[1]*0.72,"At "+r"$\mathrm{m^{gen}_{H}=}$"+f"{Higgoperaass} GeV", fontsize=24, color="black", ha='right')


    ## finalizing
    if density==True:   suffix='_AU'
    if stack==True:     suffix='_stack'
#    plt.savefig("plots/"+'M_mumu2'+suffix+".pdf", bbox_inches='tight')
    plt.savefig("plots/"+'test_photon_pt'+".pdf", bbox_inches='tight')
    plt.show()

# %%
#plot(sample=events['mc'], variable='Particle.PT')
plot(sample=events_opera35['opera35'],  variable='test_photon_pt')

# %% [markdown]
# # form factor

# %% [markdown]
# ## form1-3

# %%
use_helvet = False ## true: use helvetica for plots, make sure the system have the font installed
if use_helvet:
    CMShelvet = hep.style.CMS
    CMShelvet['font.sans-serif'] = ['Helvetica', 'Arial']
    plt.style.use(CMShelvet)
else:
    plt.style.use(hep.style.CMS)

filedict_form13={
    'form13': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_Form/ZG_nTGC_NANOGEN_form100to300.root'
}

events_form13 = {key: {} for key in filedict_form13}

for key in filedict_form13:
    events_form13[key] = uproot.lazy({filedict_form13[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])

    
##录入pt
photon_pt_form13 = events_form13['form13']['LHEPart_pt'][:,2:7][events_form13['form13']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==13]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-13]
print(photon_pt_form13)
xsec_form13 = sum(events_form13['form13']['LHEWeight_originalXWGTUP']*events_form13['form13']['LHEReweightingWeight'])/10000
print(xsec_form13)
xsec_form13_cg = xsec_form13[0]
#print(xsec_form13_cg)
xsec_form13_cgm = xsec_form13[1]
xsec_form13_CBtWL4 = xsec_form13[2]
# Out:
# [[105], [160], [110], [118], [117], [156, ... [113], [112], [135], [123], [121]]
# [0.147, 0.147, 0.147]

# %% [markdown]
# ## form3-5

# %%
filedict_form35={
    'form35': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_Form/ZG_nTGC_NANOGEN_form300to500.root'
}

events_form35 = {key: {} for key in filedict_form35}

for key in filedict_form35:
    events_form35[key] = uproot.lazy({filedict_form35[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])

    
##录入pt
photon_pt_form35 = events_form35['form35']['LHEPart_pt'][:,2:7][events_form35['form35']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==35]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-35]
print(photon_pt_form35) 
xsec_form35 = sum(events_form35['form35']['LHEWeight_originalXWGTUP']*events_form35['form35']['LHEReweightingWeight'])/10000
print(xsec_form35)
xsec_form35_cg = xsec_form35[0]
#print(xsec_form35_cg)
xsec_form35_cgm = xsec_form35[1]
xsec_form35_CBtWL4 = xsec_form35[2]
# Out:
# [[302], [310], [393], [303], [300], [323, ... [356], [314], [446], [314], [310]]
# [0.00294, 0.0031, 0.00294]

# %% [markdown]
# ## form5-6

# %%
filedict_form56={
    'form56': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_Form/ZG_nTGC_NANOGEN_form500to600.root'
}

events_form56 = {key: {} for key in filedict_form56}

for key in filedict_form56:
    events_form56[key] = uproot.lazy({filedict_form56[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])
    
##录入pt
photon_pt_form56 = events_form56['form56']['LHEPart_pt'][:,2:7][events_form56['form56']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==56]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-56]
print(photon_pt_form56)
xsec_form56 = sum(events_form56['form56']['LHEWeight_originalXWGTUP']*events_form56['form56']['LHEReweightingWeight'])/10000
print(xsec_form56)
xsec_form56_cg = xsec_form56[0]
#print(xsec_form56_cg)
xsec_form56_cgm = xsec_form56[1]
xsec_form56_CBtWL4 = xsec_form56[2]
# Out:
# [[562], [546], [508], [559], [515], [518, ... [600], [544], [501], [584], [552]]
# [0.000219, 0.000297, 0.000219]

# %% [markdown]
# ## form6-7

# %%
filedict_form67={
    'form67': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_Form/ZG_nTGC_NANOGEN_form600to700.root'
}

events_form67 = {key: {} for key in filedict_form67}

for key in filedict_form67:
    events_form67[key] = uproot.lazy({filedict_form67[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])
    
##录入pt
photon_pt_form67 = events_form67['form67']['LHEPart_pt'][:,2:7][events_form67['form67']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==67]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-67]
print(photon_pt_form67)
xsec_form67 = sum(events_form67['form67']['LHEWeight_originalXWGTUP']*events_form67['form67']['LHEReweightingWeight'])/10000
print(xsec_form67)
xsec_form67_cg = xsec_form67[0]
#print(xsec_form67_cg)
xsec_form67_cgm = xsec_form67[1]
xsec_form67_CBtWL4 = xsec_form67[2]
# Out:
# [[603], [640], [683], [649], [606], [660, ... [619], [617], [666], [638], [613]]
# [8.6e-05, 0.00117, 8.63e-05]

# %% [markdown]
# ## form7-1

# %%
filedict_form71={
    'form71': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_Form/ZG_nTGC_NANOGEN_form700to1000.root'
}

events_form71 = {key: {} for key in filedict_form71}

for key in filedict_form71:
    events_form71[key] = uproot.lazy({filedict_form71[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])
    
    
##录入pt
photon_pt_form71 = events_form71['form71']['LHEPart_pt'][:,2:7][events_form71['form71']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==71]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-71]
print(photon_pt_form71)
xsec_form71 = sum(events_form71['form71']['LHEWeight_originalXWGTUP']*events_form71['form71']['LHEReweightingWeight'])/10000
print(xsec_form71)
xsec_form71_cg = xsec_form71[0]
#print(xsec_form71_cg)
xsec_form71_cgm = xsec_form71[1]
xsec_form71_CBtWL4 = xsec_form71[2]
# Out:
# [[743], [742], [888], [795], [997], [756, ... [775], [813], [715], [713], [901]]
# [6.28e-05, 0.000892, 6.38e-05]

# %% [markdown]
# ## form1000-3000

# %%
filedict_form1030={
    'form1030': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_Form/ZG_nTGC_NANOGEN_form1000to3000.root'
}

events_form1030 = {key: {} for key in filedict_form1030}

for key in filedict_form1030:
    events_form1030[key] = uproot.lazy({filedict_form1030[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])
    
    
##录入pt
photon_pt_form1030 = events_form1030['form1030']['LHEPart_pt'][:,2:7][events_form1030['form1030']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==1030]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-1030]
print(photon_pt_form1030)
xsec_form1030 = sum(events_form1030['form1030']['LHEWeight_originalXWGTUP']*events_form1030['form1030']['LHEReweightingWeight'])/10000
print(xsec_form1030)
xsec_form1030_cg = xsec_form1030[0]
#print(xsec_form1030_cg)
xsec_form1030_cgm = xsec_form1030[1]
xsec_form1030_CBtWL4 = xsec_form1030[2]
# Out:
# [[1e+03], [1.23e+03], [1.2e+03], ... [1.17e+03], [1.23e+03], [1.11e+03]]
# [9.25e-06, 0.00343, 1.09e-05]

# %% [markdown]
# ## form3-i

# %%
filedict_form3i={
    'form3i': '~/genproductions/bin/MadGraph5_aMCatNLO/ZG/ZG_Form/ZG_nTGC_NANOGEN_form3000toinfinite.root'
}

events_form3i = {key: {} for key in filedict_form3i}

for key in filedict_form3i:
    events_form3i[key] = uproot.lazy({filedict_form3i[key]: "Events"}) ## lazy means lazy computation style
    ## optional: uproot.lazy({ "$FILEPATH": "TTree", ...}) or uproot.lazy(["$FILEPATH:TTree", ...])
    
    
##录入pt
photon_pt_form3i = events_form3i['form3i']['LHEPart_pt'][:,2:7][events_form3i['form3i']['LHEPart_pdgId'][:,2:7]==22]
#a = events['mc']['Particle.Px'][events['mc']['Particle.PID']==3i]+events['mc']['Particle.Px'][events['mc']['Particle.PID']==-3i]
print(photon_pt_form3i)
xsec_form3i = sum(events_form3i['form3i']['LHEWeight_originalXWGTUP']*events_form3i['form3i']['LHEReweightingWeight'])/10000
print(xsec_form3i)
xsec_form3i_cg = xsec_form3i[0]
#print(xsec_form3i_cg)
xsec_form3i_cgm = xsec_form3i[1]
xsec_form3i_CBtWL4 = xsec_form3i[2]
# Out:
# [[3.03e+03], [3.12e+03], [3.06e+03], ... [3.12e+03], [3.07e+03], [3.19e+03]]
# [1.54e-09, 0.000787, 4.67e-08]

# %% [markdown]
# ## 画图

# %%
def plot(sample, variable, bins=20, x_min=0, x_max=6100, density=False, stack=False):
    ## canvas initializing
    colorlist=['red', 'blue', 'green', 'black', 'cyan', 'darkorange', 'darkviolet', 'SlateGray', 'HotPink', 'LightSkyBlue']
    mpl.rcParams['axes.prop_cycle'] = cycler(color=colorlist)
    #f, ax = plt.subplots()
    plt.figure(figsize=(9,9))
    ax=plt.gca()
    plt.grid()
    hep.cms.label(data=False, year=2022, ax=ax)
#    hep.cms.label(data=False, year=MC, ax=ax)
    
    
    ## plot
    hist_form13_cg = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_form35_cg = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_form56_cg = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_form67_cg = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_form71_cg = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_form1030_cg = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())    
    hist_form3i_cg = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    #    hist_form = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
#    values = np.squeeze(sample[variable][sample['Particle.PID']==13])

    values_form13_cg = np.squeeze(photon_pt_form13)
    values_form35_cg = np.squeeze(photon_pt_form35)
    values_form56_cg = np.squeeze(photon_pt_form56)
    values_form67_cg = np.squeeze(photon_pt_form67)
    values_form71_cg = np.squeeze(photon_pt_form71)
    values_form1030_cg = np.squeeze(photon_pt_form1030)
    values_form3i_cg = np.squeeze(photon_pt_form3i)
#    values_form = np.squeeze(photon_pt_form13 + photon_pt_form35)
    
    hist_form13_cg.fill(values_form13_cg)
    hist_form35_cg.fill(values_form35_cg)
    hist_form56_cg.fill(values_form56_cg)
    hist_form67_cg.fill(values_form67_cg)
    hist_form71_cg.fill(values_form71_cg)
    hist_form1030_cg.fill(values_form1030_cg)
    hist_form3i_cg.fill(values_form3i_cg)
#    hist_form.fill(values_form)
    
    h_form13_cg, err_form13_cg = hist_form13_cg.view().value*xsec_form13_cg, np.sqrt(hist_form13_cg.view().variance)*xsec_form13_cg
    h_form35_cg, err_form35_cg = hist_form35_cg.view().value*xsec_form35_cg, np.sqrt(hist_form35_cg.view().variance)*xsec_form35_cg
    h_form56_cg, err_form56_cg = hist_form56_cg.view().value*xsec_form56_cg, np.sqrt(hist_form56_cg.view().variance)*xsec_form56_cg
    h_form67_cg, err_form67_cg = hist_form67_cg.view().value*xsec_form67_cg, np.sqrt(hist_form67_cg.view().variance)*xsec_form67_cg
    h_form71_cg, err_form71_cg = hist_form71_cg.view().value*xsec_form71_cg, np.sqrt(hist_form71_cg.view().variance)*xsec_form71_cg
    h_form1030_cg, err_form1030_cg = hist_form1030_cg.view().value*xsec_form1030_cg, np.sqrt(hist_form1030_cg.view().variance)*xsec_form1030_cg
    h_form3i_cg, err_form3i_cg = hist_form3i_cg.view().value*xsec_form3i_cg, np.sqrt(hist_form3i_cg.view().variance)*xsec_form3i_cg
    #    h_form, err_form = hist_form.view().value, np.sqrt(hist_form.view().variance)
    
    
    hep.histplot(h_form13_cg, bins=hist_form13_cg.axes[0].edges, yerr=err_form13_cg, label='form_pt100to300_cg', histtype='step', density=density, stack=stack)
    hep.histplot(h_form35_cg, bins=hist_form35_cg.axes[0].edges, yerr=err_form35_cg, label='form_pt300to500_cg', histtype='step', density=density, stack=stack)
    hep.histplot(h_form56_cg, bins=hist_form56_cg.axes[0].edges, yerr=err_form56_cg, label='form_pt500to600_cg', histtype='step', density=density, stack=stack)
    hep.histplot(h_form67_cg, bins=hist_form67_cg.axes[0].edges, yerr=err_form67_cg, label='form_pt600to700_cg', histtype='step', density=density, stack=stack)
    hep.histplot(h_form71_cg, bins=hist_form71_cg.axes[0].edges, yerr=err_form71_cg, label='form_pt700to1000_cg', histtype='step', density=density, stack=stack)
    hep.histplot(h_form1030_cg, bins=hist_form1030_cg.axes[0].edges, yerr=err_form1030_cg, label='form_pt1000to3000_cg', histtype='step', density=density, stack=stack)
    hep.histplot(h_form3i_cg, bins=hist_form3i_cg.axes[0].edges, yerr=err_form3i_cg, label='form_pt3000toinfinite_cg', histtype='step', density=density, stack=stack)

    #    hep.histplot(h_form, bins=hist_form.axes[0].edges, yerr=err_form, label='form_pt100to800', histtype='step', density=density, stack=stack)
    # or you can specify color='blue' in the above function to cover colorlist (you could comment out colorlist too) 


    ## axises
#    plt.xlim(x_min, x_max)
    plt.xlim(0, 6100)
#    plt.ylim(0, ax.get_ylim()[1]*1.1) 
    ax.ticklabel_format(useOffset=False, style='plain')
    plt.yscale('log') 
    
    if density==False:
        plt.ylabel('Events', fontsize=20, ha='right', y=1)
    elif density==True:    
        plt.ylabel('A.U.', fontsize=20, ha='right', y=1)
    plt.xlabel('photon_pt', fontsize=20, ha='right', x=1)

    plt.xticks(size=16)
    plt.yticks(size=16)

    ## title, text and legend
    #plt.title('ROC Curve of HWW4q vs. QCD', fontsize=24,color="black")
    plt.legend(loc="best", ncol=1, frameon=False, fontsize=20)
    #plt.text(0.96*ax.get_xlim()[1], ax.get_ylim()[1]*0.72,"At "+r"$\mathrm{m^{gen}_{H}=}$"+f"{Higgformass} GeV", fontsize=24, color="black", ha='right')


    ## finalizing
    if density==True:   suffix='_AU'
    if stack==True:     suffix='_stack'
#    plt.savefig("plots/"+'M_mumu2'+suffix+".pdf", bbox_inches='tight')
    plt.savefig("plots/"+'test_photon_pt'+".pdf", bbox_inches='tight')
    plt.show()

# %%
#plot(sample=events['mc'], variable='Particle.PT')
plot(sample=events_form35['form35'],  variable='test_photon_pt')

# %%
def plot(sample, variable, bins=20, x_min=0, x_max=6100, density=False, stack=False):
    ## canvas initializing
    colorlist=['red', 'blue', 'green', 'black', 'cyan', 'darkorange', 'darkviolet', 'SlateGray', 'HotPink', 'LightSkyBlue']
    mpl.rcParams['axes.prop_cycle'] = cycler(color=colorlist)
    #f, ax = plt.subplots()
    plt.figure(figsize=(9,9))
    ax=plt.gca()
    plt.grid()
    hep.cms.label(data=False, year=2022, ax=ax)
#    hep.cms.label(data=False, year=MC, ax=ax)
    
    
    ## plot
    hist_form13_cgm = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_form35_cgm = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_form56_cgm = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_form67_cgm = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_form71_cgm = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_form1030_cgm = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())    
    hist_form3i_cgm = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    #    hist_form = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
#    values = np.squeeze(sample[variable][sample['Particle.PID']==13])

    values_form13_cgm = np.squeeze(photon_pt_form13)
    values_form35_cgm = np.squeeze(photon_pt_form35)
    values_form56_cgm = np.squeeze(photon_pt_form56)
    values_form67_cgm = np.squeeze(photon_pt_form67)
    values_form71_cgm = np.squeeze(photon_pt_form71)
    values_form1030_cgm = np.squeeze(photon_pt_form1030)
    values_form3i_cgm = np.squeeze(photon_pt_form3i)
#    values_form = np.squeeze(photon_pt_form13 + photon_pt_form35)
    
    hist_form13_cgm.fill(values_form13_cgm)
    hist_form35_cgm.fill(values_form35_cgm)
    hist_form56_cgm.fill(values_form56_cgm)
    hist_form67_cgm.fill(values_form67_cgm)
    hist_form71_cgm.fill(values_form71_cgm)
    hist_form1030_cgm.fill(values_form1030_cgm)
    hist_form3i_cgm.fill(values_form3i_cgm)
#    hist_form.fill(values_form)
    
    h_form13_cgm, err_form13_cgm = hist_form13_cgm.view().value*xsec_form13_cgm, np.sqrt(hist_form13_cgm.view().variance)*xsec_form13_cgm
    h_form35_cgm, err_form35_cgm = hist_form35_cgm.view().value*xsec_form35_cgm, np.sqrt(hist_form35_cgm.view().variance)*xsec_form35_cgm
    h_form56_cgm, err_form56_cgm = hist_form56_cgm.view().value*xsec_form56_cgm, np.sqrt(hist_form56_cgm.view().variance)*xsec_form56_cgm
    h_form67_cgm, err_form67_cgm = hist_form67_cgm.view().value*xsec_form67_cgm, np.sqrt(hist_form67_cgm.view().variance)*xsec_form67_cgm
    h_form71_cgm, err_form71_cgm = hist_form71_cgm.view().value*xsec_form71_cgm, np.sqrt(hist_form71_cgm.view().variance)*xsec_form71_cgm
    h_form1030_cgm, err_form1030_cgm = hist_form1030_cgm.view().value*xsec_form1030_cgm, np.sqrt(hist_form1030_cgm.view().variance)*xsec_form1030_cgm
    h_form3i_cgm, err_form3i_cgm = hist_form3i_cgm.view().value*xsec_form3i_cgm, np.sqrt(hist_form3i_cgm.view().variance)*xsec_form3i_cgm
    #    h_form, err_form = hist_form.view().value, np.sqrt(hist_form.view().variance)
    
    
    hep.histplot(h_form13_cgm, bins=hist_form13_cgm.axes[0].edges, yerr=err_form13_cgm, label='form_pt100to300_cgm', histtype='step', density=density, stack=stack)
    hep.histplot(h_form35_cgm, bins=hist_form35_cgm.axes[0].edges, yerr=err_form35_cgm, label='form_pt300to500_cgm', histtype='step', density=density, stack=stack)
    hep.histplot(h_form56_cgm, bins=hist_form56_cgm.axes[0].edges, yerr=err_form56_cgm, label='form_pt500to600_cgm', histtype='step', density=density, stack=stack)
    hep.histplot(h_form67_cgm, bins=hist_form67_cgm.axes[0].edges, yerr=err_form67_cgm, label='form_pt600to700_cgm', histtype='step', density=density, stack=stack)
    hep.histplot(h_form71_cgm, bins=hist_form71_cgm.axes[0].edges, yerr=err_form71_cgm, label='form_pt700to1000_cgm', histtype='step', density=density, stack=stack)
    hep.histplot(h_form1030_cgm, bins=hist_form1030_cgm.axes[0].edges, yerr=err_form1030_cgm, label='form_pt1000to3000_cgm', histtype='step', density=density, stack=stack)
    hep.histplot(h_form3i_cgm, bins=hist_form3i_cgm.axes[0].edges, yerr=err_form3i_cgm, label='form_pt3000toinfinite_cgm', histtype='step', density=density, stack=stack)

    #    hep.histplot(h_form, bins=hist_form.axes[0].edges, yerr=err_form, label='form_pt100to800', histtype='step', density=density, stack=stack)
    # or you can specify color='blue' in the above function to cover colorlist (you could comment out colorlist too) 


    ## axises
#    plt.xlim(x_min, x_max)
    plt.xlim(0, 6100)
#    plt.ylim(0, ax.get_ylim()[1]*1.1) 
    ax.ticklabel_format(useOffset=False, style='plain')
    plt.yscale('log') 
    
    if density==False:
        plt.ylabel('Events', fontsize=20, ha='right', y=1)
    elif density==True:    
        plt.ylabel('A.U.', fontsize=20, ha='right', y=1)
    plt.xlabel('photon_pt', fontsize=20, ha='right', x=1)

    plt.xticks(size=16)
    plt.yticks(size=16)

    ## title, text and legend
    #plt.title('ROC Curve of HWW4q vs. QCD', fontsize=24,color="black")
    plt.legend(loc="best", ncol=1, frameon=False, fontsize=20)
    #plt.text(0.96*ax.get_xlim()[1], ax.get_ylim()[1]*0.72,"At "+r"$\mathrm{m^{gen}_{H}=}$"+f"{Higgformass} GeV", fontsize=24, color="black", ha='right')


    ## finalizing
    if density==True:   suffix='_AU'
    if stack==True:     suffix='_stack'
#    plt.savefig("plots/"+'M_mumu2'+suffix+".pdf", bbox_inches='tight')
    plt.savefig("plots/"+'test_photon_pt'+".pdf", bbox_inches='tight')
    plt.show()

# %%
#plot(sample=events['mc'], variable='Particle.PT')
plot(sample=events_form35['form35'],  variable='test_photon_pt')

# %%
def plot(sample, variable, bins=20, x_min=0, x_max=6100, density=False, stack=False):
    ## canvas initializing
    colorlist=['red', 'blue', 'green', 'black', 'cyan', 'darkorange', 'darkviolet', 'SlateGray', 'HotPink', 'LightSkyBlue']
    mpl.rcParams['axes.prop_cycle'] = cycler(color=colorlist)
    #f, ax = plt.subplots()
    plt.figure(figsize=(9,9))
    ax=plt.gca()
    plt.grid()
    hep.cms.label(data=False, year=2022, ax=ax)
#    hep.cms.label(data=False, year=MC, ax=ax)
    
    
    ## plot
    hist_form13_CBtWL4 = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_form35_CBtWL4 = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_form56_CBtWL4 = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_form67_CBtWL4 = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_form71_CBtWL4 = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_form1030_CBtWL4 = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())    
    hist_form3i_CBtWL4 = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    #    hist_form = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
#    values = np.squeeze(sample[variable][sample['Particle.PID']==13])

    values_form13_CBtWL4 = np.squeeze(photon_pt_form13)
    values_form35_CBtWL4 = np.squeeze(photon_pt_form35)
    values_form56_CBtWL4 = np.squeeze(photon_pt_form56)
    values_form67_CBtWL4 = np.squeeze(photon_pt_form67)
    values_form71_CBtWL4 = np.squeeze(photon_pt_form71)
    values_form1030_CBtWL4 = np.squeeze(photon_pt_form1030)
    values_form3i_CBtWL4 = np.squeeze(photon_pt_form3i)
#    values_form = np.squeeze(photon_pt_form13 + photon_pt_form35)
    
    hist_form13_CBtWL4.fill(values_form13_CBtWL4)
    hist_form35_CBtWL4.fill(values_form35_CBtWL4)
    hist_form56_CBtWL4.fill(values_form56_CBtWL4)
    hist_form67_CBtWL4.fill(values_form67_CBtWL4)
    hist_form71_CBtWL4.fill(values_form71_CBtWL4)
    hist_form1030_CBtWL4.fill(values_form1030_CBtWL4)
    hist_form3i_CBtWL4.fill(values_form3i_CBtWL4)
#    hist_form.fill(values_form)
    
    h_form13_CBtWL4, err_form13_CBtWL4 = hist_form13_CBtWL4.view().value*xsec_form13_CBtWL4, np.sqrt(hist_form13_CBtWL4.view().variance)*xsec_form13_CBtWL4
    h_form35_CBtWL4, err_form35_CBtWL4 = hist_form35_CBtWL4.view().value*xsec_form35_CBtWL4, np.sqrt(hist_form35_CBtWL4.view().variance)*xsec_form35_CBtWL4
    h_form56_CBtWL4, err_form56_CBtWL4 = hist_form56_CBtWL4.view().value*xsec_form56_CBtWL4, np.sqrt(hist_form56_CBtWL4.view().variance)*xsec_form56_CBtWL4
    h_form67_CBtWL4, err_form67_CBtWL4 = hist_form67_CBtWL4.view().value*xsec_form67_CBtWL4, np.sqrt(hist_form67_CBtWL4.view().variance)*xsec_form67_CBtWL4
    h_form71_CBtWL4, err_form71_CBtWL4 = hist_form71_CBtWL4.view().value*xsec_form71_CBtWL4, np.sqrt(hist_form71_CBtWL4.view().variance)*xsec_form71_CBtWL4
    h_form1030_CBtWL4, err_form1030_CBtWL4 = hist_form1030_CBtWL4.view().value*xsec_form1030_CBtWL4, np.sqrt(hist_form1030_CBtWL4.view().variance)*xsec_form1030_CBtWL4
    h_form3i_CBtWL4, err_form3i_CBtWL4 = hist_form3i_CBtWL4.view().value*xsec_form3i_CBtWL4, np.sqrt(hist_form3i_CBtWL4.view().variance)*xsec_form3i_CBtWL4
    #    h_form, err_form = hist_form.view().value, np.sqrt(hist_form.view().variance)
    
    
    hep.histplot(h_form13_CBtWL4, bins=hist_form13_CBtWL4.axes[0].edges, yerr=err_form13_CBtWL4, label='form_pt100to300_CBtWL4', histtype='step', density=density, stack=stack)
    hep.histplot(h_form35_CBtWL4, bins=hist_form35_CBtWL4.axes[0].edges, yerr=err_form35_CBtWL4, label='form_pt300to500_CBtWL4', histtype='step', density=density, stack=stack)
    hep.histplot(h_form56_CBtWL4, bins=hist_form56_CBtWL4.axes[0].edges, yerr=err_form56_CBtWL4, label='form_pt500to600_CBtWL4', histtype='step', density=density, stack=stack)
    hep.histplot(h_form67_CBtWL4, bins=hist_form67_CBtWL4.axes[0].edges, yerr=err_form67_CBtWL4, label='form_pt600to700_CBtWL4', histtype='step', density=density, stack=stack)
    hep.histplot(h_form71_CBtWL4, bins=hist_form71_CBtWL4.axes[0].edges, yerr=err_form71_CBtWL4, label='form_pt700to1000_CBtWL4', histtype='step', density=density, stack=stack)
    hep.histplot(h_form1030_CBtWL4, bins=hist_form1030_CBtWL4.axes[0].edges, yerr=err_form1030_CBtWL4, label='form_pt1000to3000_CBtWL4', histtype='step', density=density, stack=stack)
    hep.histplot(h_form3i_CBtWL4, bins=hist_form3i_CBtWL4.axes[0].edges, yerr=err_form3i_CBtWL4, label='form_pt3000toinfinite_CBtWL4', histtype='step', density=density, stack=stack)

    #    hep.histplot(h_form, bins=hist_form.axes[0].edges, yerr=err_form, label='form_pt100to800', histtype='step', density=density, stack=stack)
    # or you can specify color='blue' in the above function to cover colorlist (you could comment out colorlist too) 


    ## axises
#    plt.xlim(x_min, x_max)
    plt.xlim(0, 6100)
#    plt.ylim(0, ax.get_ylim()[1]*1.1) 
    ax.ticklabel_format(useOffset=False, style='plain')
    plt.yscale('log') 
    
    if density==False:
        plt.ylabel('Events', fontsize=20, ha='right', y=1)
    elif density==True:    
        plt.ylabel('A.U.', fontsize=20, ha='right', y=1)
    plt.xlabel('photon_pt', fontsize=20, ha='right', x=1)

    plt.xticks(size=16)
    plt.yticks(size=16)

    ## title, text and legend
    #plt.title('ROC Curve of HWW4q vs. QCD', fontsize=24,color="black")
    plt.legend(loc="best", ncol=1, frameon=False, fontsize=20)
    #plt.text(0.96*ax.get_xlim()[1], ax.get_ylim()[1]*0.72,"At "+r"$\mathrm{m^{gen}_{H}=}$"+f"{Higgformass} GeV", fontsize=24, color="black", ha='right')


    ## finalizing
    if density==True:   suffix='_AU'
    if stack==True:     suffix='_stack'
#    plt.savefig("plots/"+'M_mumu2'+suffix+".pdf", bbox_inches='tight')
    plt.savefig("plots/"+'test_photon_pt'+".pdf", bbox_inches='tight')
    plt.show()

# %%
#plot(sample=events['mc'], variable='Particle.PT')
plot(sample=events_form35['form35'],  variable='test_photon_pt')

# %%
def plot(sample, variable, bins=20, x_min=900, x_max=3100, density=False, stack=False):
    ## canvas initializing
    colorlist=['red', 'blue', 'green', 'black', 'cyan', 'darkorange', 'darkviolet', 'SlateGray', 'HotPink', 'LightSkyBlue']
    mpl.rcParams['axes.prop_cycle'] = cycler(color=colorlist)
    #f, ax = plt.subplots()
    plt.figure(figsize=(9,9))
    ax=plt.gca()
    plt.grid()
    hep.cms.label(data=False, year=2018, ax=ax)
#    hep.cms.label(data=False, year=MC, ax=ax)
    



##plot
    hist_sm1030 = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_opera1030_h4z = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_opera1030_h3a = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_opera1030_h3z = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_form1030_cg = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_form1030_cgm = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
    hist_form1030_CBtWL4 = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
#    hist_form = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())

#    values = np.squeeze(sample[variable][sample['Particle.PID']==13])
    values_sm1030 = np.squeeze(photon_pt_sm1030)
    values_opera1030_h4z = np.squeeze(photon_pt_opera1030)
    values_opera1030_h3a = np.squeeze(photon_pt_opera1030)
    values_opera1030_h3z = np.squeeze(photon_pt_opera1030)
    values_form1030_cg = np.squeeze(photon_pt_form1030)
    values_form1030_cgm = np.squeeze(photon_pt_form1030)
    values_form1030_CBtWL4 = np.squeeze(photon_pt_form1030)
#    values_form = np.squeeze(photon_pt_form13 + photon_pt_form35)

    hist_sm1030.fill(values_sm1030)
    hist_opera1030_h4z.fill(values_opera1030_h4z)
    hist_opera1030_h3a.fill(values_opera1030_h3a)
    hist_opera1030_h3z.fill(values_opera1030_h3z)
    hist_form1030_cg.fill(values_form1030_cg)
    hist_form1030_cgm.fill(values_form1030_cgm)
    hist_form1030_CBtWL4.fill(values_form1030_CBtWL4)
#    hist_form.fill(values_form)

    h_sm1030, err_sm1030 = hist_sm1030.view().value*1.01, np.sqrt(hist_sm1030.view().variance)*1.01
    h_opera1030_h4z, err_opera1030_h4z = hist_opera1030_h4z.view().value*xsec_opera1030_h4z, np.sqrt(hist_opera1030_h4z.view().variance)*xsec_opera1030_h4z
    h_opera1030_h3a, err_opera1030_h3a = hist_opera1030_h3a.view().value*xsec_opera1030_h3a, np.sqrt(hist_opera1030_h3a.view().variance)*xsec_opera1030_h3a
    h_opera1030_h3z, err_opera1030_h3z = hist_opera1030_h3z.view().value*xsec_opera1030_h3z, np.sqrt(hist_opera1030_h3z.view().variance)*xsec_opera1030_h3z
    h_form1030_cg, err_form1030_cg = hist_form1030_cg.view().value*xsec_form1030_cg, np.sqrt(hist_form1030_cg.view().variance)*xsec_form1030_cg
    h_form1030_cgm, err_form1030_cgm = hist_form1030_cgm.view().value*xsec_form1030_cgm, np.sqrt(hist_form1030_cgm.view().variance)*xsec_form1030_cgm
    h_form1030_CBtWL4, err_form1030_CBtWL4 = hist_form1030_CBtWL4.view().value*xsec_form1030_CBtWL4, np.sqrt(hist_form1030_CBtWL4.view().variance)*xsec_form1030_CBtWL4
#    h_form, err_form = hist_form.view().value, np.sqrt(hist_form.view().variance)

    hep.histplot(h_sm1030, bins=hist_sm1030.axes[0].edges, yerr=err_sm1030, label='sm_pt1000to3000', histtype='step', density=density, stack=stack)
    hep.histplot(h_opera1030_h4z, bins=hist_opera1030_h4z.axes[0].edges, yerr=err_opera1030_h4z, label='opera_pt1000to3000_h4z', histtype='step', density=density, stack=stack)
    hep.histplot(h_opera1030_h3a, bins=hist_opera1030_h3a.axes[0].edges, yerr=err_opera1030_h3a, label='opera_pt1000to3000_h3a', histtype='step', density=density, stack=stack)
    hep.histplot(h_opera1030_h3z, bins=hist_opera1030_h3z.axes[0].edges, yerr=err_opera1030_h3z, label='opera_pt1000to3000_h3z', histtype='step', density=density, stack=stack)
    hep.histplot(h_form1030_cg, bins=hist_form1030_cg.axes[0].edges, yerr=err_form1030_cg, label='form_pt1000to3000_cg', histtype='step', density=density, stack=stack)    
    hep.histplot(h_form1030_cgm, bins=hist_form1030_cgm.axes[0].edges, yerr=err_form1030_cgm, label='form_pt1000to3000_cgm', histtype='step', density=density, stack=stack)
    hep.histplot(h_form1030_CBtWL4, bins=hist_form1030_CBtWL4.axes[0].edges, yerr=err_form1030_CBtWL4, label='form_pt1000to3000_CBtWL4', histtype='step', density=density, stack=stack)
#    hep.histplot(h_form, bins=hist_form.axes[0].edges, yerr=err_form, label='form_pt100to800', histtype='step', density=density, stack=stack)
    # or you can specify color='blue' in the above function to cover colorlist (you could comment out colorlist too) 


    ## axises
#    plt.xlim(x_min, x_max)
    plt.xlim(900, 3100)
#    plt.ylim(0, ax.get_ylim()[1]*1.1) 
    ax.ticklabel_format(useOffset=False, style='plain')
    plt.yscale('log') 
    
    if density==False:
        plt.ylabel('Events', fontsize=20, ha='right', y=1)
    elif density==True:    
        plt.ylabel('A.U.', fontsize=20, ha='right', y=1)
    plt.xlabel('photon_pt', fontsize=20, ha='right', x=1)

    plt.xticks(size=16)
    plt.yticks(size=16)

    ## title, text and legend
    #plt.title('ROC Curve of HWW4q vs. QCD', fontsize=24,color="black")
    plt.legend(loc="best", ncol=1, frameon=False, fontsize=20)
    #plt.text(0.96*ax.get_xlim()[1], ax.get_ylim()[1]*0.72,"At "+r"$\mathrm{m^{gen}_{H}=}$"+f"{Higgformass} GeV", fontsize=24, color="black", ha='right')


    ## finalizing
    if density==True:   suffix='_AU'
    if stack==True:     suffix='_stack'
#    plt.savefig("plots/"+'M_mumu2'+suffix+".pdf", bbox_inches='tight')
    plt.savefig("plots/"+'test_photon_pt'+".pdf", bbox_inches='tight')
    plt.show()

# %%
#plot(sample=events['mc'], variable='Particle.PT')
plot(sample=events_form35['form35'],  variable='test_photon_pt')
